# %%
import enum
import random

class Kid(enum.Enum):
  BOY = 0
  GIRL = 1


def random_kid() -> Kid:
  return random.choice([Kid.BOY, Kid.GIRL])


def probability_example(iterations):
  both_girls = 0
  older_girl = 0
  either_girl = 0


  random.seed(0)


  for _ in range(iterations):
     younger = random_kid()
     older = random_kid()

  if older == Kid.GIRL:
    older_girl += 1
  if older == Kid.GIRL and younger == Kid.GIRL:
    both_girls += 1
  if older == Kid.GIRL or younger == Kid.GIRL:
    either_girl += 1


# Conditional Probability: P(both | older)
  conditional_prob_both_given_older = both_girls / older_girl


# Conditional Probability: P(both | either)
  conditional_prob_both_given_either = both_girls / either_girl


# Joint Probability: P(either_girls)
  joint_prob_either_girls = (either_girl / iterations) * 100


# Joint Probability: P(both_girls)
  joint_prob_both_girls = (both_girls / iterations) * 100


# Joint Probability: P(older_girl)
  joint_prob_older_girl = (older_girl / iterations) * 100

  print("Conditional Probability - P(both | older):", conditional_prob_both_given_older)
  print("Conditional Probability - P(both | either):",
  conditional_prob_both_given_either)
  print("Joint Probability - P(either_girls):", joint_prob_either_girls)
  print("Joint Probability - P(both_girls):", joint_prob_both_girls)
  print("Joint Probability - P(older_girl):", joint_prob_older_girl)

  if   name  == "  main  ":
# Get user input for the number of iterations
    iterations = int(input("Enter the number of iterations: "))


# Run the probability example with user-specified iterations probability_example(iterations)
  probability_example(iterations)

# %%
import enum, random
print("saurabh Yadav 60")
class Kid(enum.Enum):
  BOY = 0
  GIRL = 1
def random_kid() -> Kid:
  return random.choice([Kid.BOY,Kid.GIRL])
both_girls = 0
older_girl = 0
either_girl =0
random.seed(0)
for _ in range(10000):

  younger = random_kid()
  older =random_kid()
  if  older == Kid.GIRL:
    older_girl += 1
  if older == Kid.GIRL and younger == Kid.GIRL: both_girls += 1
  if older == Kid.GIRL or younger == Kid.GIRL:  either_girl += 1
  print("P(both | older):", both_girls / older_girl)
  print("P(both | either):", both_girls / either_girl)
  print("P(either_girls):", (either_girl/10000)*100)
  print("P(both_girls):",(both_girls/10000)*100)
  print("P(older_girl):", (older_girl/10000)*100)
# Out:
# Streaming output truncated to the last 5000 lines.
# P(both | older): 0.5001128413450688
# P(both | either): 0.3307462686567164
# P(either_girls): 67.0
# P(both_girls): 22.16
# P(older_girl): 44.31
# P(both | older): 0.5002256317689531
# P(both | either): 0.3308461423668109
# P(either_girls): 67.01
# P(both_girls): 22.17
# P(older_girl): 44.32
# P(both | older): 0.5003383713061132
# P(both | either): 0.3309459862727544
# P(either_girls): 67.02
# P(both_girls): 22.18
# P(older_girl): 44.330000000000005
# P(both | older): 0.5002255299954894
# P(both | either): 0.3308966134566612
# P(either_girls): 67.03
# P(both_girls): 22.18
# P(older_girl): 44.34
# P(both | older): 0.5002255299954894
# P(both | either): 0.3308966134566612
# P(either_girls): 67.03
# P(both_girls): 22.18
# P(older_girl): 44.34
# P(both | older): 0.5002255299954894
# P(both | either): 0.3308966134566612
# P(either_girls): 67.03
# P(both_girls): 22.18
# P(older_girl): 44.34
# P(both | older): 0.5002255299954894
# P(both | either): 0.33084725536992843
# P(either_girls): 67.04
# P(both_girls): 22.18
# P(older_girl): 44.34
# P(both | older): 0.5003382187147689
# P(both | either): 0.3309470544369873
# P(either_girls): 67.05
# P(both_girls): 22.189999999999998
# P(older_girl): 44.35
# P(both | older): 0.5003382187147689
# P(both | either): 0.3309470544369873
# P(either_girls): 67.05
# P(both_girls): 22.189999999999998
# P(older_girl): 44.35
# P(both | older): 0.5003382187147689
# P(both | either): 0.33089770354906056
# P(either_girls): 67.06
# P(both_girls): 22.189999999999998
# P(older_girl): 44.35
# P(both | older): 0.5003382187147689
# P(both | either): 0.33084836737736695
# P(either_girls): 67.07
# P(both_girls): 22.189999999999998
# P(older_girl): 44.35
# P(both | older): 0.5002254283137962
# P(both | either): 0.330799045915325
# P(either_girls): 67.08
# P(both_girls): 22.189999999999998
# P(older_girl): 44.36
# P(both | older): 0.5002254283137962
# P(both | either): 0.33074973915635714
# P(either_girls): 67.09
# P(both_girls): 22.189999999999998
# P(older_girl): 44.36
# P(both | older): 0.5002254283137962
# P(both | either): 0.33070044709388974
# P(either_girls): 67.10000000000001
# P(both_girls): 22.189999999999998
# P(older_girl): 44.36
# P(both | older): 0.5002254283137962
# P(both | either): 0.33070044709388974
# P(either_girls): 67.10000000000001
# P(both_girls): 22.189999999999998
# P(older_girl): 44.36
# P(both | older): 0.5002254283137962
# P(both | either): 0.33070044709388974
# P(either_girls): 67.10000000000001
# P(both_girls): 22.189999999999998
# P(older_girl): 44.36
# P(both | older): 0.5001126887536624
# P(both | either): 0.330651169721353
# P(either_girls): 67.11
# P(both_girls): 22.189999999999998
# P(older_girl): 44.37
# P(both | older): 0.5002253267237494
# P(both | either): 0.33075089392133494
# P(either_girls): 67.12
# P(both_girls): 22.2
# P(older_girl): 44.379999999999995
# P(both | older): 0.5003379139445822
# P(both | either): 0.3308505884105467
# P(either_girls): 67.13
# P(both_girls): 22.21
# P(older_girl): 44.39
# P(both | older): 0.5002252252252253
# P(both | either): 0.3308013106940721
# P(either_girls): 67.14
# P(both_girls): 22.21
# P(older_girl): 44.4
# P(both | older): 0.5003377617653681
# P(both | either): 0.33090096798212953
# P(either_girls): 67.15
# P(both_girls): 22.220000000000002
# P(older_girl): 44.41
# P(both | older): 0.5002251238180999
# P(both | either): 0.33085169743895176
# P(either_girls): 67.16
# P(both_girls): 22.220000000000002
# P(older_girl): 44.42
# P(both | older): 0.50033760972316
# P(both | either): 0.3309513175524788
# P(either_girls): 67.17
# P(both_girls): 22.23
# P(older_girl): 44.43
# P(both | older): 0.50033760972316
# P(both | either): 0.3309020541827925
# P(either_girls): 67.17999999999999
# P(both_girls): 22.23
# P(older_girl): 44.43
# P(both | older): 0.50033760972316
# P(both | either): 0.3308528054770055
# P(either_girls): 67.19000000000001
# P(both_girls): 22.23
# P(older_girl): 44.43
# P(both | older): 0.50033760972316
# P(both | either): 0.3308035714285714
# P(either_girls): 67.2
# P(both_girls): 22.23
# P(older_girl): 44.43
# P(both | older): 0.5004500450045004
# P(both | either): 0.3309031394137777
# P(either_girls): 67.21000000000001
# P(both_girls): 22.24
# P(older_girl): 44.440000000000005
# P(both | older): 0.5004500450045004
# P(both | either): 0.3309031394137777
# P(either_girls): 67.21000000000001
# P(both_girls): 22.24
# P(older_girl): 44.440000000000005
# P(both | older): 0.500562429696288
# P(both | either): 0.3310026777744719
# P(either_girls): 67.22
# P(both_girls): 22.25
# P(older_girl): 44.45
# P(both | older): 0.5006747638326585
# P(both | either): 0.33110218652387324
# P(either_girls): 67.23
# P(both_girls): 22.259999999999998
# P(older_girl): 44.46
# P(both | older): 0.5007870474477175
# P(both | either): 0.3312016656751933
# P(either_girls): 67.24
# P(both_girls): 22.27
# P(older_girl): 44.47
# P(both | older): 0.5007870474477175
# P(both | either): 0.3311524163568773
# P(either_girls): 67.25
# P(both_girls): 22.27
# P(older_girl): 44.47
# P(both | older): 0.5007870474477175
# P(both | either): 0.3311031816830211
# P(either_girls): 67.25999999999999
# P(both_girls): 22.27
# P(older_girl): 44.47
# P(both | older): 0.5006744604316546
# P(both | either): 0.3310539616470938
# P(either_girls): 67.27
# P(both_girls): 22.27
# P(older_girl): 44.48
# P(both | older): 0.5006744604316546
# P(both | either): 0.3310539616470938
# P(either_girls): 67.27
# P(both_girls): 22.27
# P(older_girl): 44.48
# P(both | older): 0.5005619240278715
# P(both | either): 0.33100475624256837
# P(either_girls): 67.28
# P(both_girls): 22.27
# P(older_girl): 44.49
# P(both | older): 0.5006741573033708
# P(both | either): 0.3311041759548224
# P(either_girls): 67.29
# P(both_girls): 22.28
# P(older_girl): 44.5
# P(both | older): 0.5006741573033708
# P(both | either): 0.3311041759548224
# P(either_girls): 67.29
# P(both_girls): 22.28
# P(older_girl): 44.5
# P(both | older): 0.5006741573033708
# P(both | either): 0.3310549777117385
# P(either_girls): 67.30000000000001
# P(both_girls): 22.28
# P(older_girl): 44.5
# P(both | older): 0.5007863401482813
# P(both | either): 0.3311543604219284
# P(either_girls): 67.31
# P(both_girls): 22.29
# P(older_girl): 44.51
# P(both | older): 0.5007863401482813
# P(both | either): 0.33110516934046347
# P(either_girls): 67.32000000000001
# P(both_girls): 22.29
# P(older_girl): 44.51
# P(both | older): 0.5007863401482813
# P(both | either): 0.33110516934046347
# P(either_girls): 67.32000000000001
# P(both_girls): 22.29
# P(older_girl): 44.51
# P(both | older): 0.5006738544474394
# P(both | either): 0.3310559928709342
# P(either_girls): 67.33
# P(both_girls): 22.29
# P(older_girl): 44.519999999999996
# P(both | older): 0.500785986975073
# P(both | either): 0.33115533115533113
# P(either_girls): 67.34
# P(both_girls): 22.3
# P(older_girl): 44.529999999999994
# P(both | older): 0.5006735518634935
# P(both | either): 0.33110616184112845
# P(either_girls): 67.35
# P(both_girls): 22.3
# P(older_girl): 44.54
# P(both | older): 0.5006735518634935
# P(both | either): 0.33110616184112845
# P(either_girls): 67.35
# P(both_girls): 22.3
# P(older_girl): 44.54
# P(both | older): 0.5006735518634935
# P(both | either): 0.33105700712589076
# P(either_girls): 67.36
# P(both_girls): 22.3
# P(older_girl): 44.54
# P(both | older): 0.500561167227834
# P(both | either): 0.33100786700311713
# P(either_girls): 67.36999999999999
# P(both_girls): 22.3
# P(older_girl): 44.55
# P(both | older): 0.500561167227834
# P(both | either): 0.33100786700311713
# P(either_girls): 67.36999999999999
# P(both_girls): 22.3
# P(older_girl): 44.55
# P(both | older): 0.5004488330341114
# P(both | either): 0.3309587414663105
# P(either_girls): 67.38
# P(both_girls): 22.3
# P(older_girl): 44.56
# P(both | older): 0.5005609154139555
# P(both | either): 0.3310580204778157
# P(either_girls): 67.39
# P(both_girls): 22.31
# P(older_girl): 44.57
# P(both | older): 0.5005609154139555
# P(both | either): 0.33100890207715133
# P(either_girls): 67.4
# P(both_girls): 22.31
# P(older_girl): 44.57
# P(both | older): 0.5004486316733961
# P(both | either): 0.3309597982495179
# P(either_girls): 67.41
# P(both_girls): 22.31
# P(older_girl): 44.58
# P(both | older): 0.5004486316733961
# P(both | either): 0.3309107089884307
# P(either_girls): 67.42
# P(both_girls): 22.31
# P(older_girl): 44.58
# P(both | older): 0.500336398295582
# P(both | either): 0.33086163428740917
# P(either_girls): 67.43
# P(both_girls): 22.31
# P(older_girl): 44.59
# P(both | older): 0.5004484304932736
# P(both | either): 0.3309608540925267
# P(either_girls): 67.44
# P(both_girls): 22.32
# P(older_girl): 44.6
# P(both | older): 0.5004484304932736
# P(both | either): 0.3309117865085248
# P(either_girls): 67.45
# P(both_girls): 22.32
# P(older_girl): 44.6
# P(both | older): 0.5004484304932736
# P(both | either): 0.3309117865085248
# P(either_girls): 67.45
# P(both_girls): 22.32
# P(older_girl): 44.6
# P(both | older): 0.5004484304932736
# P(both | either): 0.33086273347168693
# P(either_girls): 67.46
# P(both_girls): 22.32
# P(older_girl): 44.6
# P(both | older): 0.5004484304932736
# P(both | either): 0.33086273347168693
# P(either_girls): 67.46
# P(both_girls): 22.32
# P(older_girl): 44.6
# P(both | older): 0.5003362474781439
# P(both | either): 0.3308136949755447
# P(either_girls): 67.47
# P(both_girls): 22.32
# P(older_girl): 44.61
# P(both | older): 0.5002241147467503
# P(both | either): 0.33076467101363366
# P(either_girls): 67.47999999999999
# P(both_girls): 22.32
# P(older_girl): 44.62
# P(both | older): 0.5001120322652924
# P(both | either): 0.3307156615794933
# P(either_girls): 67.49000000000001
# P(both_girls): 22.32
# P(older_girl): 44.629999999999995
# P(both | older): 0.5001120322652924
# P(both | either): 0.3307156615794933
# P(either_girls): 67.49000000000001
# P(both_girls): 22.32
# P(older_girl): 44.629999999999995
# P(both | older): 0.5
# P(both | either): 0.33066666666666666
# P(either_girls): 67.5
# P(both_girls): 22.32
# P(older_girl): 44.64
# P(both | older): 0.5
# P(both | either): 0.33066666666666666
# P(either_girls): 67.5
# P(both_girls): 22.32
# P(older_girl): 44.64
# P(both | older): 0.5001119820828668
# P(both | either): 0.33076581247222636
# P(either_girls): 67.51
# P(both_girls): 22.33
# P(older_girl): 44.65
# P(both | older): 0.5
# P(both | either): 0.33071682464454977
# P(either_girls): 67.52
# P(both_girls): 22.33
# P(older_girl): 44.66
# P(both | older): 0.5001119319453772
# P(both | either): 0.3308159336591145
# P(either_girls): 67.53
# P(both_girls): 22.34
# P(older_girl): 44.67
# P(both | older): 0.5001119319453772
# P(both | either): 0.3308159336591145
# P(either_girls): 67.53
# P(both_girls): 22.34
# P(older_girl): 44.67
# P(both | older): 0.5
# P(both | either): 0.33076695291679004
# P(either_girls): 67.54
# P(both_girls): 22.34
# P(older_girl): 44.68
# P(both | older): 0.5001118818527635
# P(both | either): 0.3308660251665433
# P(either_girls): 67.55
# P(both_girls): 22.35
# P(older_girl): 44.690000000000005
# P(both | older): 0.5001118818527635
# P(both | either): 0.3308660251665433
# P(either_girls): 67.55
# P(both_girls): 22.35
# P(older_girl): 44.690000000000005
# P(both | older): 0.5001118818527635
# P(both | either): 0.3308660251665433
# P(either_girls): 67.55
# P(both_girls): 22.35
# P(older_girl): 44.690000000000005
# P(both | older): 0.5001118818527635
# P(both | either): 0.3308660251665433
# P(either_girls): 67.55
# P(both_girls): 22.35
# P(older_girl): 44.690000000000005
# P(both | older): 0.5001118818527635
# P(both | either): 0.3308170515097691
# P(either_girls): 67.56
# P(both_girls): 22.35
# P(older_girl): 44.690000000000005
# P(both | older): 0.5001118818527635
# P(both | either): 0.33076809234867544
# P(either_girls): 67.57
# P(both_girls): 22.35
# P(older_girl): 44.690000000000005
# P(both | older): 0.5001118818527635
# P(both | either): 0.3307191476768275
# P(either_girls): 67.58
# P(both_girls): 22.35
# P(older_girl): 44.690000000000005
# P(both | older): 0.5
# P(both | either): 0.33067021748779407
# P(either_girls): 67.58999999999999
# P(both_girls): 22.35
# P(older_girl): 44.7
# P(both | older): 0.5
# P(both | either): 0.3306213017751479
# P(either_girls): 67.60000000000001
# P(both_girls): 22.35
# P(older_girl): 44.7
# P(both | older): 0.5
# P(both | either): 0.3305724005324656
# P(either_girls): 67.61
# P(both_girls): 22.35
# P(older_girl): 44.7
# P(both | older): 0.5
# P(both | either): 0.3305724005324656
# P(either_girls): 67.61
# P(both_girls): 22.35
# P(older_girl): 44.7
# P(both | older): 0.5
# P(both | either): 0.3305724005324656
# P(either_girls): 67.61
# P(both_girls): 22.35
# P(older_girl): 44.7
# P(both | older): 0.5
# P(both | either): 0.3305724005324656
# P(either_girls): 67.61
# P(both_girls): 22.35
# P(older_girl): 44.7
# P(both | older): 0.5001118318049653
# P(both | either): 0.33067139899438036
# P(either_girls): 67.62
# P(both_girls): 22.36
# P(older_girl): 44.71
# P(both | older): 0.5002236135957067
# P(both | either): 0.3307703681798019
# P(either_girls): 67.63
# P(both_girls): 22.37
# P(older_girl): 44.72
# P(both | older): 0.500335345405768
# P(both | either): 0.33086930810171494
# P(either_girls): 67.64
# P(both_girls): 22.38
# P(older_girl): 44.73
# P(both | older): 0.500335345405768
# P(both | either): 0.33086930810171494
# P(either_girls): 67.64
# P(both_girls): 22.38
# P(older_girl): 44.73
# P(both | older): 0.5004470272686634
# P(both | either): 0.33096821877309685
# P(either_girls): 67.65
# P(both_girls): 22.39
# P(older_girl): 44.74
# P(both | older): 0.5003351955307263
# P(both | either): 0.33091930239432454
# P(either_girls): 67.66
# P(both_girls): 22.39
# P(older_girl): 44.75
# P(both | older): 0.5003351955307263
# P(both | either): 0.33087040047288313
# P(either_girls): 67.67
# P(both_girls): 22.39
# P(older_girl): 44.75
# P(both | older): 0.5004468275245755
# P(both | either): 0.3309692671394799
# P(either_girls): 67.67999999999999
# P(both_girls): 22.400000000000002
# P(older_girl): 44.76
# P(both | older): 0.5004468275245755
# P(both | either): 0.3309203722854188
# P(either_girls): 67.69
# P(both_girls): 22.400000000000002
# P(older_girl): 44.76
# P(both | older): 0.5005584096493187
# P(both | either): 0.3310192023633678
# P(either_girls): 67.7
# P(both_girls): 22.41
# P(older_girl): 44.769999999999996
# P(both | older): 0.5006699419383653
# P(both | either): 0.3311180032491508
# P(either_girls): 67.71000000000001
# P(both_girls): 22.42
# P(older_girl): 44.78
# P(both | older): 0.5005581603036392
# P(both | either): 0.3310691080921441
# P(either_girls): 67.72
# P(both_girls): 22.42
# P(older_girl): 44.79
# P(both | older): 0.5005581603036392
# P(both | either): 0.3310691080921441
# P(either_girls): 67.72
# P(both_girls): 22.42
# P(older_girl): 44.79
# P(both | older): 0.5005581603036392
# P(both | either): 0.33102022737339437
# P(either_girls): 67.73
# P(both_girls): 22.42
# P(older_girl): 44.79
# P(both | older): 0.5006696428571429
# P(both | either): 0.3311189843519339
# P(either_girls): 67.74
# P(both_girls): 22.43
# P(older_girl): 44.800000000000004
# P(both | older): 0.5006696428571429
# P(both | either): 0.3311189843519339
# P(either_girls): 67.74
# P(both_girls): 22.43
# P(older_girl): 44.800000000000004
# P(both | older): 0.50055791118054
# P(both | either): 0.33107011070110703
# P(either_girls): 67.75
# P(both_girls): 22.43
# P(older_girl): 44.81
# P(both | older): 0.50055791118054
# P(both | either): 0.3310212514757969
# P(either_girls): 67.75999999999999
# P(both_girls): 22.43
# P(older_girl): 44.81
# P(both | older): 0.500669344042838
# P(both | either): 0.33111996458610005
# P(either_girls): 67.77
# P(both_girls): 22.439999999999998
# P(older_girl): 44.82
# P(both | older): 0.5007807271916127
# P(both | either): 0.3312186485688994
# P(either_girls): 67.78
# P(both_girls): 22.45
# P(older_girl): 44.83
# P(both | older): 0.5008920606601249
# P(both | either): 0.3313173034370851
# P(either_girls): 67.78999999999999
# P(both_girls): 22.46
# P(older_girl): 44.84
# P(both | older): 0.5008920606601249
# P(both | either): 0.33126843657817107
# P(either_girls): 67.80000000000001
# P(both_girls): 22.46
# P(older_girl): 44.84
# P(both | older): 0.5008920606601249
# P(both | either): 0.33126843657817107
# P(either_girls): 67.80000000000001
# P(both_girls): 22.46
# P(older_girl): 44.84
# P(both | older): 0.5008920606601249
# P(both | either): 0.3312195841321339
# P(either_girls): 67.81
# P(both_girls): 22.46
# P(older_girl): 44.84
# P(both | older): 0.5010033444816053
# P(both | either): 0.33131819522264816
# P(either_girls): 67.82000000000001
# P(both_girls): 22.470000000000002
# P(older_girl): 44.85
# P(both | older): 0.5010033444816053
# P(both | either): 0.33131819522264816
# P(either_girls): 67.82000000000001
# P(both_girls): 22.470000000000002
# P(older_girl): 44.85
# P(both | older): 0.5010033444816053
# P(both | either): 0.33131819522264816
# P(either_girls): 67.82000000000001
# P(both_girls): 22.470000000000002
# P(older_girl): 44.85
# P(both | older): 0.5008916629514044
# P(both | either): 0.33126934984520123
# P(either_girls): 67.83
# P(both_girls): 22.470000000000002
# P(older_girl): 44.86
# P(both | older): 0.5008916629514044
# P(both | either): 0.33126934984520123
# P(either_girls): 67.83
# P(both_girls): 22.470000000000002
# P(older_girl): 44.86
# P(both | older): 0.5010028972587475
# P(both | either): 0.3313679245283019
# P(either_girls): 67.84
# P(both_girls): 22.48
# P(older_girl): 44.87
# P(both | older): 0.5010028972587475
# P(both | either): 0.33131908621960204
# P(either_girls): 67.85
# P(both_girls): 22.48
# P(older_girl): 44.87
# P(both | older): 0.5008912655971479
# P(both | either): 0.33127026230474504
# P(either_girls): 67.86
# P(both_girls): 22.48
# P(older_girl): 44.879999999999995
# P(both | older): 0.5008912655971479
# P(both | either): 0.3312214527773685
# P(either_girls): 67.86999999999999
# P(both_girls): 22.48
# P(older_girl): 44.879999999999995
# P(both | older): 0.5007796836711963
# P(both | either): 0.33117265763111375
# P(either_girls): 67.88
# P(both_girls): 22.48
# P(older_girl): 44.89
# P(both | older): 0.5008908685968819
# P(both | either): 0.33127117395787303
# P(either_girls): 67.89
# P(both_girls): 22.49
# P(older_girl): 44.9
# P(both | older): 0.5008908685968819
# P(both | either): 0.33127117395787303
# P(either_girls): 67.89
# P(both_girls): 22.49
# P(older_girl): 44.9
# P(both | older): 0.501002004008016
# P(both | either): 0.33136966126656847
# P(either_girls): 67.9
# P(both_girls): 22.5
# P(older_girl): 44.91
# P(both | older): 0.501002004008016
# P(both | either): 0.33136966126656847
# P(either_girls): 67.9
# P(both_girls): 22.5
# P(older_girl): 44.91
# P(both | older): 0.501113089937667
# P(both | either): 0.33146811957001915
# P(either_girls): 67.91
# P(both_girls): 22.509999999999998
# P(older_girl): 44.92
# P(both | older): 0.5010015579790785
# P(both | either): 0.33141931684334514
# P(either_girls): 67.92
# P(both_girls): 22.509999999999998
# P(older_girl): 44.93
# P(both | older): 0.5008900756564308
# P(both | either): 0.3313705284852054
# P(either_girls): 67.93
# P(both_girls): 22.509999999999998
# P(older_girl): 44.940000000000005
# P(both | older): 0.5007786429365962
# P(both | either): 0.3313217544892552
# P(either_girls): 67.94
# P(both_girls): 22.509999999999998
# P(older_girl): 44.95
# P(both | older): 0.5007786429365962
# P(both | either): 0.3313217544892552
# P(either_girls): 67.94
# P(both_girls): 22.509999999999998
# P(older_girl): 44.95
# P(both | older): 0.5007786429365962
# P(both | either): 0.3313217544892552
# P(either_girls): 67.94
# P(both_girls): 22.509999999999998
# P(older_girl): 44.95
# P(both | older): 0.5007786429365962
# P(both | either): 0.3313217544892552
# P(either_girls): 67.94
# P(both_girls): 22.509999999999998
# P(older_girl): 44.95
# P(both | older): 0.5007786429365962
# P(both | either): 0.3312729948491538
# P(either_girls): 67.95
# P(both_girls): 22.509999999999998
# P(older_girl): 44.95
# P(both | older): 0.5007786429365962
# P(both | either): 0.3312242495585639
# P(either_girls): 67.96
# P(both_girls): 22.509999999999998
# P(older_girl): 44.95
# P(both | older): 0.5008896797153025
# P(both | either): 0.3313226423422098
# P(either_girls): 67.97
# P(both_girls): 22.52
# P(older_girl): 44.96
# P(both | older): 0.5010006671114076
# P(both | either): 0.33142100617828774
# P(either_girls): 67.97999999999999
# P(both_girls): 22.53
# P(older_girl): 44.97
# P(both | older): 0.5010006671114076
# P(both | either): 0.33142100617828774
# P(either_girls): 67.97999999999999
# P(both_girls): 22.53
# P(older_girl): 44.97
# P(both | older): 0.5011116051578479
# P(both | either): 0.33151934107957054
# P(either_girls): 67.99
# P(both_girls): 22.54
# P(older_girl): 44.98
# P(both | older): 0.5011116051578479
# P(both | either): 0.33151934107957054
# P(either_girls): 67.99
# P(both_girls): 22.54
# P(older_girl): 44.98
# P(both | older): 0.5011116051578479
# P(both | either): 0.33147058823529413
# P(either_girls): 68.0
# P(both_girls): 22.54
# P(older_girl): 44.98
# P(both | older): 0.5011116051578479
# P(both | either): 0.33142184972798117
# P(either_girls): 68.01
# P(both_girls): 22.54
# P(older_girl): 44.98
# P(both | older): 0.5010002222716159
# P(both | either): 0.33137312555130843
# P(either_girls): 68.02
# P(both_girls): 22.54
# P(older_girl): 44.99
# P(both | older): 0.5011111111111111
# P(both | either): 0.33147140967220345
# P(either_girls): 68.03
# P(both_girls): 22.55
# P(older_girl): 45.0
# P(both | older): 0.5009997778271496
# P(both | either): 0.33142269253380363
# P(either_girls): 68.04
# P(both_girls): 22.55
# P(older_girl): 45.01
# P(both | older): 0.5011106175033319
# P(both | either): 0.3315209404849375
# P(either_girls): 68.05
# P(both_girls): 22.56
# P(older_girl): 45.019999999999996
# P(both | older): 0.5011106175033319
# P(both | either): 0.33147223038495444
# P(either_girls): 68.06
# P(both_girls): 22.56
# P(older_girl): 45.019999999999996
# P(both | older): 0.5009993337774816
# P(both | either): 0.3314235345967387
# P(either_girls): 68.07
# P(both_girls): 22.56
# P(older_girl): 45.03
# P(both | older): 0.5011101243339254
# P(both | either): 0.33152173913043476
# P(either_girls): 68.08
# P(both_girls): 22.57
# P(older_girl): 45.04
# P(both | older): 0.5012208657047724
# P(both | either): 0.3316199148186224
# P(either_girls): 68.08999999999999
# P(both_girls): 22.58
# P(older_girl): 45.050000000000004
# P(both | older): 0.5012208657047724
# P(both | either): 0.3315712187958884
# P(either_girls): 68.10000000000001
# P(both_girls): 22.58
# P(older_girl): 45.050000000000004
# P(both | older): 0.5012208657047724
# P(both | either): 0.3315712187958884
# P(either_girls): 68.10000000000001
# P(both_girls): 22.58
# P(older_girl): 45.050000000000004
# P(both | older): 0.5012208657047724
# P(both | either): 0.3315225370723829
# P(either_girls): 68.11
# P(both_girls): 22.58
# P(older_girl): 45.050000000000004
# P(both | older): 0.5012208657047724
# P(both | either): 0.3315225370723829
# P(either_girls): 68.11
# P(both_girls): 22.58
# P(older_girl): 45.050000000000004
# P(both | older): 0.501109631602308
# P(both | either): 0.3314738696418086
# P(either_girls): 68.12
# P(both_girls): 22.58
# P(older_girl): 45.06
# P(both | older): 0.5009984468604393
# P(both | either): 0.3314252164978717
# P(either_girls): 68.13
# P(both_girls): 22.58
# P(older_girl): 45.07
# P(both | older): 0.501109139307897
# P(both | either): 0.33152333431171116
# P(either_girls): 68.14
# P(both_girls): 22.59
# P(older_girl): 45.08
# P(both | older): 0.5012197826569084
# P(both | either): 0.33162142333088773
# P(either_girls): 68.15
# P(both_girls): 22.6
# P(older_girl): 45.09
# P(both | older): 0.5011086474501109
# P(both | either): 0.3315727699530516
# P(either_girls): 68.16
# P(both_girls): 22.6
# P(older_girl): 45.1
# P(both | older): 0.5011086474501109
# P(both | either): 0.33152413084934723
# P(either_girls): 68.17
# P(both_girls): 22.6
# P(older_girl): 45.1
# P(both | older): 0.5011086474501109
# P(both | either): 0.33152413084934723
# P(either_girls): 68.17
# P(both_girls): 22.6
# P(older_girl): 45.1
# P(both | older): 0.5009975615162935
# P(both | either): 0.3314755060134937
# P(either_girls): 68.17999999999999
# P(both_girls): 22.6
# P(older_girl): 45.11
# P(both | older): 0.5009975615162935
# P(both | either): 0.33142689543921394
# P(either_girls): 68.19
# P(both_girls): 22.6
# P(older_girl): 45.11
# P(both | older): 0.500886524822695
# P(both | either): 0.3313782991202346
# P(either_girls): 68.2
# P(both_girls): 22.6
# P(older_girl): 45.12
# P(both | older): 0.500886524822695
# P(both | either): 0.3313782991202346
# P(either_girls): 68.2
# P(both_girls): 22.6
# P(older_girl): 45.12
# P(both | older): 0.500886524822695
# P(both | either): 0.3313782991202346
# P(either_girls): 68.2
# P(both_girls): 22.6
# P(older_girl): 45.12
# P(both | older): 0.500886524822695
# P(both | either): 0.3313782991202346
# P(either_girls): 68.2
# P(both_girls): 22.6
# P(older_girl): 45.12
# P(both | older): 0.5007755373365832
# P(both | either): 0.33132971705028585
# P(either_girls): 68.21000000000001
# P(both_girls): 22.6
# P(older_girl): 45.129999999999995
# P(both | older): 0.500886132033673
# P(both | either): 0.331427733802404
# P(either_girls): 68.22
# P(both_girls): 22.61
# P(older_girl): 45.14
# P(both | older): 0.500886132033673
# P(both | either): 0.331427733802404
# P(either_girls): 68.22
# P(both_girls): 22.61
# P(older_girl): 45.14
# P(both | older): 0.500886132033673
# P(both | either): 0.331427733802404
# P(either_girls): 68.22
# P(both_girls): 22.61
# P(older_girl): 45.14
# P(both | older): 0.5007751937984496
# P(both | either): 0.33137915872783236
# P(either_girls): 68.23
# P(both_girls): 22.61
# P(older_girl): 45.15
# P(both | older): 0.5007751937984496
# P(both | either): 0.3313305978898007
# P(either_girls): 68.24
# P(both_girls): 22.61
# P(older_girl): 45.15
# P(both | older): 0.5006643046944198
# P(both | either): 0.3312820512820513
# P(either_girls): 68.25
# P(both_girls): 22.61
# P(older_girl): 45.16
# P(both | older): 0.500774850564534
# P(both | either): 0.33138001757984176
# P(either_girls): 68.26
# P(both_girls): 22.62
# P(older_girl): 45.17
# P(both | older): 0.50066401062417
# P(both | either): 0.331331477955178
# P(either_girls): 68.27
# P(both_girls): 22.62
# P(older_girl): 45.18
# P(both | older): 0.5005532197388802
# P(both | either): 0.3312829525483304
# P(either_girls): 68.28
# P(both_girls): 22.62
# P(older_girl): 45.190000000000005
# P(both | older): 0.5006637168141593
# P(both | either): 0.33138087567725877
# P(either_girls): 68.28999999999999
# P(both_girls): 22.63
# P(older_girl): 45.2
# P(both | older): 0.5007741650077416
# P(both | either): 0.33147877013177157
# P(either_girls): 68.30000000000001
# P(both_girls): 22.64
# P(older_girl): 45.21
# P(both | older): 0.5007741650077416
# P(both | either): 0.3314302444737227
# P(either_girls): 68.31
# P(both_girls): 22.64
# P(older_girl): 45.21
# P(both | older): 0.5008845643520566
# P(both | either): 0.3315281030444965
# P(either_girls): 68.32000000000001
# P(both_girls): 22.650000000000002
# P(older_girl): 45.22
# P(both | older): 0.5008845643520566
# P(both | either): 0.3315281030444965
# P(either_girls): 68.32000000000001
# P(both_girls): 22.650000000000002
# P(older_girl): 45.22
# P(both | older): 0.5008845643520566
# P(both | either): 0.33147958436996927
# P(either_girls): 68.33
# P(both_girls): 22.650000000000002
# P(older_girl): 45.22
# P(both | older): 0.5007738226840592
# P(both | either): 0.33143107989464443
# P(either_girls): 68.34
# P(both_girls): 22.650000000000002
# P(older_girl): 45.23
# P(both | older): 0.5006631299734748
# P(both | either): 0.33138258961228967
# P(either_girls): 68.35
# P(both_girls): 22.650000000000002
# P(older_girl): 45.24
# P(both | older): 0.5005524861878453
# P(both | either): 0.3313341135166764
# P(either_girls): 68.36
# P(both_girls): 22.650000000000002
# P(older_girl): 45.25
# P(both | older): 0.5004418912947415
# P(both | either): 0.33128565160157963
# P(either_girls): 68.37
# P(both_girls): 22.650000000000002
# P(older_girl): 45.26
# P(both | older): 0.5005522421029379
# P(both | either): 0.3313834454518865
# P(either_girls): 68.38
# P(both_girls): 22.66
# P(older_girl): 45.269999999999996
# P(both | older): 0.5004416961130742
# P(both | either): 0.3313349904956865
# P(either_girls): 68.39
# P(both_girls): 22.66
# P(older_girl): 45.28
# P(both | older): 0.5003311989401634
# P(both | either): 0.33128654970760235
# P(either_girls): 68.4
# P(both_girls): 22.66
# P(older_girl): 45.29
# P(both | older): 0.5002207505518764
# P(both | either): 0.33123812308142087
# P(either_girls): 68.41000000000001
# P(both_girls): 22.66
# P(older_girl): 45.300000000000004
# P(both | older): 0.5002207505518764
# P(both | either): 0.3311897106109325
# P(either_girls): 68.42
# P(both_girls): 22.66
# P(older_girl): 45.300000000000004
# P(both | older): 0.5002207505518764
# P(both | either): 0.3311897106109325
# P(either_girls): 68.42
# P(both_girls): 22.66
# P(older_girl): 45.300000000000004
# P(both | older): 0.5001103509159126
# P(both | either): 0.3311413122899313
# P(either_girls): 68.43
# P(both_girls): 22.66
# P(older_girl): 45.31
# P(both | older): 0.5001103509159126
# P(both | either): 0.3311413122899313
# P(either_girls): 68.43
# P(both_girls): 22.66
# P(older_girl): 45.31
# P(both | older): 0.5
# P(both | either): 0.3310929281122151
# P(either_girls): 68.44
# P(both_girls): 22.66
# P(older_girl): 45.32
# P(both | older): 0.499889697771895
# P(both | either): 0.3310445580715851
# P(either_girls): 68.45
# P(both_girls): 22.66
# P(older_girl): 45.33
# P(both | older): 0.4997794441993824
# P(both | either): 0.33099620216184633
# P(either_girls): 68.46
# P(both_girls): 22.66
# P(older_girl): 45.34
# P(both | older): 0.4996692392502756
# P(both | either): 0.33094786037680735
# P(either_girls): 68.47
# P(both_girls): 22.66
# P(older_girl): 45.35
# P(both | older): 0.4996692392502756
# P(both | either): 0.33094786037680735
# P(either_girls): 68.47
# P(both_girls): 22.66
# P(older_girl): 45.35
# P(both | older): 0.49955908289241624
# P(both | either): 0.3308995327102804
# P(either_girls): 68.47999999999999
# P(both_girls): 22.66
# P(older_girl): 45.36
# P(both | older): 0.49966938505620456
# P(both | either): 0.3309972258723901
# P(either_girls): 68.49
# P(both_girls): 22.67
# P(older_girl): 45.37
# P(both | older): 0.499779638607316
# P(both | either): 0.3310948905109489
# P(either_girls): 68.5
# P(both_girls): 22.68
# P(older_girl): 45.379999999999995
# P(both | older): 0.499779638607316
# P(both | either): 0.33104656254561377
# P(either_girls): 68.51
# P(both_girls): 22.68
# P(older_girl): 45.379999999999995
# P(both | older): 0.499779638607316
# P(both | either): 0.33104656254561377
# P(either_girls): 68.51
# P(both_girls): 22.68
# P(older_girl): 45.379999999999995
# P(both | older): 0.499779638607316
# P(both | either): 0.3309982486865149
# P(either_girls): 68.52000000000001
# P(both_girls): 22.68
# P(older_girl): 45.379999999999995
# P(both | older): 0.4996695307336418
# P(both | either): 0.33094994892747703
# P(either_girls): 68.53
# P(both_girls): 22.68
# P(older_girl): 45.39
# P(both | older): 0.4996695307336418
# P(both | either): 0.33090166326232856
# P(either_girls): 68.54
# P(both_girls): 22.68
# P(older_girl): 45.39
# P(both | older): 0.49977973568281936
# P(both | either): 0.3309992706053975
# P(either_girls): 68.55
# P(both_girls): 22.689999999999998
# P(older_girl): 45.4
# P(both | older): 0.49977973568281936
# P(both | either): 0.3309992706053975
# P(either_girls): 68.55
# P(both_girls): 22.689999999999998
# P(older_girl): 45.4
# P(both | older): 0.4998898920942524
# P(both | either): 0.33109684947491247
# P(either_girls): 68.56
# P(both_girls): 22.7
# P(older_girl): 45.410000000000004
# P(both | older): 0.5
# P(both | either): 0.3311943998833309
# P(either_girls): 68.57
# P(both_girls): 22.71
# P(older_girl): 45.42
# P(both | older): 0.49988994056790664
# P(both | either): 0.3311461067366579
# P(either_girls): 68.58
# P(both_girls): 22.71
# P(older_girl): 45.43
# P(both | older): 0.5
# P(both | either): 0.3312436215191719
# P(either_girls): 68.58999999999999
# P(both_girls): 22.720000000000002
# P(older_girl): 45.440000000000005
# P(both | older): 0.5
# P(both | either): 0.33119533527696793
# P(either_girls): 68.60000000000001
# P(both_girls): 22.720000000000002
# P(older_girl): 45.440000000000005
# P(both | older): 0.5001100110011001
# P(both | either): 0.33129281445853376
# P(either_girls): 68.61
# P(both_girls): 22.73
# P(older_girl): 45.45
# P(both | older): 0.5001100110011001
# P(both | either): 0.331244535120956
# P(either_girls): 68.62
# P(both_girls): 22.73
# P(older_girl): 45.45
# P(both | older): 0.5001100110011001
# P(both | either): 0.331196269852834
# P(either_girls): 68.63
# P(both_girls): 22.73
# P(older_girl): 45.45
# P(both | older): 0.5001100110011001
# P(both | either): 0.331196269852834
# P(either_girls): 68.63
# P(both_girls): 22.73
# P(older_girl): 45.45
# P(both | older): 0.5001100110011001
# P(both | either): 0.331196269852834
# P(either_girls): 68.63
# P(both_girls): 22.73
# P(older_girl): 45.45
# P(both | older): 0.5002199736031676
# P(both | either): 0.3312937062937063
# P(either_girls): 68.64
# P(both_girls): 22.74
# P(older_girl): 45.46
# P(both | older): 0.5002199736031676
# P(both | either): 0.3312937062937063
# P(either_girls): 68.64
# P(both_girls): 22.74
# P(older_girl): 45.46
# P(both | older): 0.5002199736031676
# P(both | either): 0.3312937062937063
# P(either_girls): 68.64
# P(both_girls): 22.74
# P(older_girl): 45.46
# P(both | older): 0.5002199736031676
# P(both | either): 0.3312454479242535
# P(either_girls): 68.65
# P(both_girls): 22.74
# P(older_girl): 45.46
# P(both | older): 0.5002199736031676
# P(both | either): 0.3312454479242535
# P(either_girls): 68.65
# P(both_girls): 22.74
# P(older_girl): 45.46
# P(both | older): 0.5002199736031676
# P(both | either): 0.3312454479242535
# P(either_girls): 68.65
# P(both_girls): 22.74
# P(older_girl): 45.46
# P(both | older): 0.5002199736031676
# P(both | either): 0.3312454479242535
# P(either_girls): 68.65
# P(both_girls): 22.74
# P(older_girl): 45.46
# P(both | older): 0.5001099626127117
# P(both | either): 0.33119720361200117
# P(either_girls): 68.66
# P(both_girls): 22.74
# P(older_girl): 45.47
# P(both | older): 0.5
# P(both | either): 0.33114897335080823
# P(either_girls): 68.67
# P(both_girls): 22.74
# P(older_girl): 45.48
# P(both | older): 0.5
# P(both | either): 0.33110075713453696
# P(either_girls): 68.67999999999999
# P(both_girls): 22.74
# P(older_girl): 45.48
# P(both | older): 0.5001099142668718
# P(both | either): 0.33119813655553937
# P(either_girls): 68.69
# P(both_girls): 22.75
# P(older_girl): 45.49
# P(both | older): 0.5001099142668718
# P(both | either): 0.33119813655553937
# P(either_girls): 68.69
# P(both_girls): 22.75
# P(older_girl): 45.49
# P(both | older): 0.5001099142668718
# P(both | either): 0.33119813655553937
# P(either_girls): 68.69
# P(both_girls): 22.75
# P(older_girl): 45.49
# P(both | older): 0.5001099142668718
# P(both | either): 0.33119813655553937
# P(either_girls): 68.69
# P(both_girls): 22.75
# P(older_girl): 45.49
# P(both | older): 0.5002197802197802
# P(both | either): 0.3312954876273654
# P(either_girls): 68.7
# P(both_girls): 22.759999999999998
# P(older_girl): 45.5
# P(both | older): 0.5003295978905735
# P(both | either): 0.33139281036239265
# P(either_girls): 68.71000000000001
# P(both_girls): 22.770000000000003
# P(older_girl): 45.51
# P(both | older): 0.5003295978905735
# P(both | either): 0.3313445867287544
# P(either_girls): 68.72
# P(both_girls): 22.770000000000003
# P(older_girl): 45.51
# P(both | older): 0.5003295978905735
# P(both | either): 0.33129637712789173
# P(either_girls): 68.73
# P(both_girls): 22.770000000000003
# P(older_girl): 45.51
# P(both | older): 0.500219683655536
# P(both | either): 0.3312481815536805
# P(either_girls): 68.74
# P(both_girls): 22.770000000000003
# P(older_girl): 45.519999999999996
# P(both | older): 0.500219683655536
# P(both | either): 0.3312481815536805
# P(either_girls): 68.74
# P(both_girls): 22.770000000000003
# P(older_girl): 45.519999999999996
# P(both | older): 0.5003294531078409
# P(both | either): 0.33134545454545455
# P(either_girls): 68.75
# P(both_girls): 22.78
# P(older_girl): 45.53
# P(both | older): 0.5004391743522179
# P(both | either): 0.33144269924374636
# P(either_girls): 68.76
# P(both_girls): 22.79
# P(older_girl): 45.540000000000006
# P(both | older): 0.5004391743522179
# P(both | either): 0.33139450341718774
# P(either_girls): 68.77
# P(both_girls): 22.79
# P(older_girl): 45.540000000000006
# P(both | older): 0.5005488474204172
# P(both | either): 0.3314917127071823
# P(either_girls): 68.78
# P(both_girls): 22.8
# P(older_girl): 45.550000000000004
# P(both | older): 0.5004389815627743
# P(both | either): 0.3314435237679895
# P(either_girls): 68.78999999999999
# P(both_girls): 22.8
# P(older_girl): 45.56
# P(both | older): 0.5004389815627743
# P(both | either): 0.3313953488372093
# P(either_girls): 68.8
# P(both_girls): 22.8
# P(older_girl): 45.56
# P(both | older): 0.5004389815627743
# P(both | either): 0.3313471879087342
# P(either_girls): 68.81
# P(both_girls): 22.8
# P(older_girl): 45.56
# P(both | older): 0.5004389815627743
# P(both | either): 0.33129904097646035
# P(either_girls): 68.82000000000001
# P(both_girls): 22.8
# P(older_girl): 45.56
# P(both | older): 0.5005486065393899
# P(both | either): 0.33139619352026733
# P(either_girls): 68.83
# P(both_girls): 22.81
# P(older_girl): 45.57
# P(both | older): 0.5004387889425187
# P(both | either): 0.3313480534572923
# P(either_girls): 68.84
# P(both_girls): 22.81
# P(older_girl): 45.58
# P(both | older): 0.5004387889425187
# P(both | either): 0.3313480534572923
# P(either_girls): 68.84
# P(both_girls): 22.81
# P(older_girl): 45.58
# P(both | older): 0.500329019521825
# P(both | either): 0.3312999273783587
# P(either_girls): 68.85
# P(both_girls): 22.81
# P(older_girl): 45.59
# P(both | older): 0.500329019521825
# P(both | either): 0.3312999273783587
# P(either_girls): 68.85
# P(both_girls): 22.81
# P(older_girl): 45.59
# P(both | older): 0.5002192982456141
# P(both | either): 0.3312518152773744
# P(either_girls): 68.86
# P(both_girls): 22.81
# P(older_girl): 45.6
# P(both | older): 0.5001096250822188
# P(both | either): 0.3312037171482503
# P(either_girls): 68.87
# P(both_girls): 22.81
# P(older_girl): 45.61
# P(both | older): 0.5
# P(both | either): 0.3311556329849013
# P(either_girls): 68.88
# P(both_girls): 22.81
# P(older_girl): 45.62
# P(both | older): 0.5
# P(both | either): 0.3311075627812455
# P(either_girls): 68.89
# P(both_girls): 22.81
# P(older_girl): 45.62
# P(both | older): 0.49989042296734604
# P(both | either): 0.33105950653120464
# P(either_girls): 68.89999999999999
# P(both_girls): 22.81
# P(older_girl): 45.629999999999995
# P(both | older): 0.49989042296734604
# P(both | either): 0.33105950653120464
# P(either_girls): 68.89999999999999
# P(both_girls): 22.81
# P(older_girl): 45.629999999999995
# P(both | older): 0.49989042296734604
# P(both | either): 0.3310114642287041
# P(either_girls): 68.91000000000001
# P(both_girls): 22.81
# P(older_girl): 45.629999999999995
# P(both | older): 0.49989042296734604
# P(both | either): 0.3310114642287041
# P(either_girls): 68.91000000000001
# P(both_girls): 22.81
# P(older_girl): 45.629999999999995
# P(both | older): 0.4997808939526731
# P(both | either): 0.3309634358676727
# P(either_girls): 68.92
# P(both_girls): 22.81
# P(older_girl): 45.64
# P(both | older): 0.49967141292442496
# P(both | either): 0.33091542144204267
# P(either_girls): 68.93
# P(both_girls): 22.81
# P(older_girl): 45.65
# P(both | older): 0.49967141292442496
# P(both | either): 0.33086742094574995
# P(either_girls): 68.94
# P(both_girls): 22.81
# P(older_girl): 45.65
# P(both | older): 0.49967141292442496
# P(both | either): 0.33081943437273387
# P(either_girls): 68.95
# P(both_girls): 22.81
# P(older_girl): 45.65
# P(both | older): 0.49956197985107315
# P(both | either): 0.33077146171693733
# P(either_girls): 68.96
# P(both_girls): 22.81
# P(older_girl): 45.660000000000004
# P(both | older): 0.49967155682067005
# P(both | either): 0.33086849354791936
# P(either_girls): 68.97
# P(both_girls): 22.82
# P(older_girl): 45.67
# P(both | older): 0.49967155682067005
# P(both | either): 0.33086849354791936
# P(either_girls): 68.97
# P(both_girls): 22.82
# P(older_girl): 45.67
# P(both | older): 0.49978108581436076
# P(both | either): 0.33096549724557844
# P(either_girls): 68.97999999999999
# P(both_girls): 22.830000000000002
# P(older_girl): 45.68
# P(both | older): 0.4998905668636463
# P(both | either): 0.3310624728221481
# P(either_girls): 68.99
# P(both_girls): 22.84
# P(older_girl): 45.69
# P(both | older): 0.5
# P(both | either): 0.33115942028985507
# P(either_girls): 69.0
# P(both_girls): 22.85
# P(older_girl): 45.7
# P(both | older): 0.5
# P(both | either): 0.33115942028985507
# P(either_girls): 69.0
# P(both_girls): 22.85
# P(older_girl): 45.7
# P(both | older): 0.49989061474513236
# P(both | either): 0.33111143312563396
# P(either_girls): 69.01
# P(both_girls): 22.85
# P(older_girl): 45.71
# P(both | older): 0.5
# P(both | either): 0.33120834540712835
# P(either_girls): 69.02000000000001
# P(both_girls): 22.86
# P(older_girl): 45.72
# P(both | older): 0.5001093374152635
# P(both | either): 0.33130522961031433
# P(either_girls): 69.03
# P(both_girls): 22.869999999999997
# P(older_girl): 45.73
# P(both | older): 0.5002186270222999
# P(both | either): 0.3314020857473928
# P(either_girls): 69.04
# P(both_girls): 22.88
# P(older_girl): 45.739999999999995
# P(both | older): 0.5001092896174864
# P(both | either): 0.3313540912382332
# P(either_girls): 69.05
# P(both_girls): 22.88
# P(older_girl): 45.75
# P(both | older): 0.5002185314685315
# P(both | either): 0.3314509122502172
# P(either_girls): 69.06
# P(both_girls): 22.89
# P(older_girl): 45.76
# P(both | older): 0.5003277255844439
# P(both | either): 0.3315477052265817
# P(either_girls): 69.07
# P(both_girls): 22.900000000000002
# P(older_girl): 45.769999999999996
# P(both | older): 0.500436871996505
# P(both | either): 0.33164447017950205
# P(either_girls): 69.08
# P(both_girls): 22.91
# P(older_girl): 45.78
# P(both | older): 0.5003275824415812
# P(both | either): 0.3315964683745839
# P(either_girls): 69.08999999999999
# P(both_girls): 22.91
# P(older_girl): 45.79
# P(both | older): 0.5002183406113537
# P(both | either): 0.331548480463097
# P(either_girls): 69.1
# P(both_girls): 22.91
# P(older_girl): 45.800000000000004
# P(both | older): 0.5001091464745688
# P(both | either): 0.3315005064390103
# P(either_girls): 69.11
# P(both_girls): 22.91
# P(older_girl): 45.81
# P(both | older): 0.5
# P(both | either): 0.3314525462962963
# P(either_girls): 69.12
# P(both_girls): 22.91
# P(older_girl): 45.82
# P(both | older): 0.5
# P(both | either): 0.331404600028931
# P(either_girls): 69.13
# P(both_girls): 22.91
# P(older_girl): 45.82
# P(both | older): 0.5
# P(both | either): 0.33135666763089383
# P(either_girls): 69.14
# P(both_girls): 22.91
# P(older_girl): 45.82
# P(both | older): 0.49989090115644774
# P(both | either): 0.33130874909616775
# P(either_girls): 69.15
# P(both_girls): 22.91
# P(older_girl): 45.83
# P(both | older): 0.49989090115644774
# P(both | either): 0.33126084441873915
# P(either_girls): 69.16
# P(both_girls): 22.91
# P(older_girl): 45.83
# P(both | older): 0.5
# P(both | either): 0.3313575249385572
# P(either_girls): 69.17
# P(both_girls): 22.919999999999998
# P(older_girl): 45.839999999999996
# P(both | older): 0.5
# P(both | either): 0.3313575249385572
# P(either_girls): 69.17
# P(both_girls): 22.919999999999998
# P(older_girl): 45.839999999999996
# P(both | older): 0.5001090512540894
# P(both | either): 0.33145417750795025
# P(either_girls): 69.17999999999999
# P(both_girls): 22.93
# P(older_girl): 45.85
# P(both | older): 0.5
# P(both | either): 0.3314062725827432
# P(either_girls): 69.19
# P(both_girls): 22.93
# P(older_girl): 45.86
# P(both | older): 0.5
# P(both | either): 0.33135838150289015
# P(either_girls): 69.19999999999999
# P(both_girls): 22.93
# P(older_girl): 45.86
# P(both | older): 0.499890996293874
# P(both | either): 0.33131050426238984
# P(either_girls): 69.21000000000001
# P(both_girls): 22.93
# P(older_girl): 45.87
# P(both | older): 0.499890996293874
# P(both | either): 0.33131050426238984
# P(either_girls): 69.21000000000001
# P(both_girls): 22.93
# P(older_girl): 45.87
# P(both | older): 0.499890996293874
# P(both | either): 0.33126264085524415
# P(either_girls): 69.22
# P(both_girls): 22.93
# P(older_girl): 45.87
# P(both | older): 0.49978204010462074
# P(both | either): 0.3312147912754586
# P(either_girls): 69.23
# P(both_girls): 22.93
# P(older_girl): 45.879999999999995
# P(both | older): 0.49967313140117675
# P(both | either): 0.33116695551704217
# P(either_girls): 69.24
# P(both_girls): 22.93
# P(older_girl): 45.89
# P(both | older): 0.49978213507625274
# P(both | either): 0.33126353790613716
# P(either_girls): 69.25
# P(both_girls): 22.939999999999998
# P(older_girl): 45.9
# P(both | older): 0.49978213507625274
# P(both | either): 0.33126353790613716
# P(either_girls): 69.25
# P(both_girls): 22.939999999999998
# P(older_girl): 45.9
# P(both | older): 0.49967327379655846
# P(both | either): 0.3312157089228992
# P(either_girls): 69.26
# P(both_girls): 22.939999999999998
# P(older_girl): 45.910000000000004
# P(both | older): 0.49956445993031356
# P(both | either): 0.3311678937490977
# P(either_girls): 69.27
# P(both_girls): 22.939999999999998
# P(older_girl): 45.92
# P(both | older): 0.49956445993031356
# P(both | either): 0.3311200923787529
# P(either_girls): 69.28
# P(both_girls): 22.939999999999998
# P(older_girl): 45.92
# P(both | older): 0.49956445993031356
# P(both | either): 0.3310723048058883
# P(either_girls): 69.28999999999999
# P(both_girls): 22.939999999999998
# P(older_girl): 45.92
# P(both | older): 0.49956445993031356
# P(both | either): 0.3310723048058883
# P(either_girls): 69.28999999999999
# P(both_girls): 22.939999999999998
# P(older_girl): 45.92
# P(both | older): 0.49956445993031356
# P(both | either): 0.331024531024531
# P(either_girls): 69.3
# P(both_girls): 22.939999999999998
# P(older_girl): 45.92
# P(both | older): 0.4994556934465491
# P(both | either): 0.3309767710287116
# P(either_girls): 69.31
# P(both_girls): 22.939999999999998
# P(older_girl): 45.93
# P(both | older): 0.49956464954288204
# P(both | either): 0.3310732833237161
# P(either_girls): 69.32000000000001
# P(both_girls): 22.95
# P(older_girl): 45.94
# P(both | older): 0.49956464954288204
# P(both | either): 0.3310255300735612
# P(either_girls): 69.33
# P(both_girls): 22.95
# P(older_girl): 45.94
# P(both | older): 0.49956464954288204
# P(both | either): 0.33097779059705795
# P(either_girls): 69.34
# P(both_girls): 22.95
# P(older_girl): 45.94
# P(both | older): 0.49956464954288204
# P(both | either): 0.330930064888248
# P(either_girls): 69.35
# P(both_girls): 22.95
# P(older_girl): 45.94
# P(both | older): 0.499455930359086
# P(both | either): 0.33088235294117646
# P(either_girls): 69.36
# P(both_girls): 22.95
# P(older_girl): 45.95
# P(both | older): 0.4995648389904265
# P(both | either): 0.33097880928355194
# P(either_girls): 69.37
# P(both_girls): 22.96
# P(older_girl): 45.96
# P(both | older): 0.49945616706547746
# P(both | either): 0.33093110406457193
# P(either_girls): 69.38
# P(both_girls): 22.96
# P(older_girl): 45.97
# P(both | older): 0.4993475424097434
# P(both | either): 0.3308834125954749
# P(either_girls): 69.39
# P(both_girls): 22.96
# P(older_girl): 45.98
# P(both | older): 0.4994564035659926
# P(both | either): 0.33097982708933715
# P(either_girls): 69.39999999999999
# P(both_girls): 22.97
# P(older_girl): 45.989999999999995
# P(both | older): 0.4994564035659926
# P(both | either): 0.33093214234260193
# P(either_girls): 69.41000000000001
# P(both_girls): 22.97
# P(older_girl): 45.989999999999995
# P(both | older): 0.49934782608695655
# P(both | either): 0.3308844713339095
# P(either_girls): 69.42
# P(both_girls): 22.97
# P(older_girl): 46.0
# P(both | older): 0.4992392958052597
# P(both | either): 0.3308368140573239
# P(either_girls): 69.43
# P(both_girls): 22.97
# P(older_girl): 46.01
# P(both | older): 0.4992392958052597
# P(both | either): 0.3307891705069124
# P(either_girls): 69.44
# P(both_girls): 22.97
# P(older_girl): 46.01
# P(both | older): 0.4991308126901347
# P(both | either): 0.3307415406767459
# P(either_girls): 69.45
# P(both_girls): 22.97
# P(older_girl): 46.02
# P(both | older): 0.49902237671084076
# P(both | either): 0.33069392456089836
# P(either_girls): 69.46
# P(both_girls): 22.97
# P(older_girl): 46.03
# P(both | older): 0.49902237671084076
# P(both | either): 0.3306463221534475
# P(either_girls): 69.47
# P(both_girls): 22.97
# P(older_girl): 46.03
# P(both | older): 0.49902237671084076
# P(both | either): 0.3305987334484744
# P(either_girls): 69.48
# P(both_girls): 22.97
# P(older_girl): 46.03
# P(both | older): 0.4989139878366638
# P(both | either): 0.33055115844006333
# P(either_girls): 69.49
# P(both_girls): 22.97
# P(older_girl): 46.04
# P(both | older): 0.4988056460369164
# P(both | either): 0.33050359712230215
# P(either_girls): 69.5
# P(both_girls): 22.97
# P(older_girl): 46.050000000000004
# P(both | older): 0.4989144594007816
# P(both | either): 0.33059991368148467
# P(either_girls): 69.51
# P(both_girls): 22.98
# P(older_girl): 46.06
# P(both | older): 0.4989144594007816
# P(both | either): 0.33059991368148467
# P(either_girls): 69.51
# P(both_girls): 22.98
# P(older_girl): 46.06
# P(both | older): 0.4989144594007816
# P(both | either): 0.3305523590333717
# P(either_girls): 69.52000000000001
# P(both_girls): 22.98
# P(older_girl): 46.06
# P(both | older): 0.4990232255263729
# P(both | either): 0.3306486408744427
# P(either_girls): 69.53
# P(both_girls): 22.99
# P(older_girl): 46.07
# P(both | older): 0.4990232255263729
# P(both | either): 0.33060109289617484
# P(either_girls): 69.54
# P(both_girls): 22.99
# P(older_girl): 46.07
# P(both | older): 0.4990232255263729
# P(both | either): 0.33055355859094177
# P(either_girls): 69.55
# P(both_girls): 22.99
# P(older_girl): 46.07
# P(both | older): 0.4990232255263729
# P(both | either): 0.33055355859094177
# P(either_girls): 69.55
# P(both_girls): 22.99
# P(older_girl): 46.07
# P(both | older): 0.4991319444444444
# P(both | either): 0.33064979873490513
# P(either_girls): 69.56
# P(both_girls): 23.0
# P(older_girl): 46.08
# P(both | older): 0.4990236493816446
# P(both | either): 0.3306022710938623
# P(either_girls): 69.57
# P(both_girls): 23.0
# P(older_girl): 46.089999999999996
# P(both | older): 0.49891540130151846
# P(both | either): 0.33055475711411325
# P(either_girls): 69.58
# P(both_girls): 23.0
# P(older_girl): 46.1
# P(both | older): 0.49891540130151846
# P(both | either): 0.33055475711411325
# P(either_girls): 69.58
# P(both_girls): 23.0
# ...
# P(older_girl): 48.79
# P(both | older): 0.5006147540983606
# P(both | either): 0.3312542372881356
# P(either_girls): 73.75
# P(both_girls): 24.43
# P(older_girl): 48.8
# P(both | older): 0.5005121901249744
# P(both | either): 0.33120932754880694
# P(either_girls): 73.76
# P(both_girls): 24.43
# P(older_girl): 48.809999999999995
# P(both | older): 0.5005121901249744
# P(both | either): 0.33120932754880694
# P(either_girls): 73.76
# P(both_girls): 24.43
# P(older_girl): 48.809999999999995
# P(both | older): 0.5005121901249744
# P(both | either): 0.33116442998508877
# P(either_girls): 73.77
# P(both_girls): 24.43
# P(older_girl): 48.809999999999995
# P(both | older): 0.5006145022531749
# P(both | either): 0.33125508267823256
# P(either_girls): 73.78
# P(both_girls): 24.44
# P(older_girl): 48.82
# P(both | older): 0.5006145022531749
# P(both | either): 0.33125508267823256
# P(either_girls): 73.78
# P(both_girls): 24.44
# P(older_girl): 48.82
# P(both | older): 0.5006145022531749
# P(both | either): 0.33125508267823256
# P(either_girls): 73.78
# P(both_girls): 24.44
# P(older_girl): 48.82
# P(both | older): 0.5006145022531749
# P(both | either): 0.33125508267823256
# P(either_girls): 73.78
# P(both_girls): 24.44
# P(older_girl): 48.82
# P(both | older): 0.5007167724759369
# P(both | either): 0.3313457108009215
# P(either_girls): 73.79
# P(both_girls): 24.45
# P(older_girl): 48.83
# P(both | older): 0.5007167724759369
# P(both | either): 0.3313008130081301
# P(either_girls): 73.8
# P(both_girls): 24.45
# P(older_girl): 48.83
# P(both | older): 0.5007167724759369
# P(both | either): 0.33125592738111365
# P(either_girls): 73.81
# P(both_girls): 24.45
# P(older_girl): 48.83
# P(both | older): 0.5007167724759369
# P(both | either): 0.3312110539149282
# P(either_girls): 73.82
# P(both_girls): 24.45
# P(older_girl): 48.83
# P(both | older): 0.5007167724759369
# P(both | either): 0.33116619260463226
# P(either_girls): 73.83
# P(both_girls): 24.45
# P(older_girl): 48.83
# P(both | older): 0.5006142506142506
# P(both | either): 0.3311213434452871
# P(either_girls): 73.83999999999999
# P(both_girls): 24.45
# P(older_girl): 48.84
# P(both | older): 0.5006142506142506
# P(both | either): 0.3310765064319567
# P(either_girls): 73.85000000000001
# P(both_girls): 24.45
# P(older_girl): 48.84
# P(both | older): 0.5006142506142506
# P(both | either): 0.3310316815597076
# P(either_girls): 73.86
# P(both_girls): 24.45
# P(older_girl): 48.84
# P(both | older): 0.5006142506142506
# P(both | either): 0.33098686882360906
# P(either_girls): 73.87
# P(both_girls): 24.45
# P(older_girl): 48.84
# P(both | older): 0.5006142506142506
# P(both | either): 0.33098686882360906
# P(either_girls): 73.87
# P(both_girls): 24.45
# P(older_girl): 48.84
# P(both | older): 0.5007164790174002
# P(both | either): 0.3310774228478614
# P(either_girls): 73.88
# P(both_girls): 24.46
# P(older_girl): 48.85
# P(both | older): 0.5007164790174002
# P(both | either): 0.33103261605088646
# P(either_girls): 73.89
# P(both_girls): 24.46
# P(older_girl): 48.85
# P(both | older): 0.5007164790174002
# P(both | either): 0.33103261605088646
# P(either_girls): 73.89
# P(both_girls): 24.46
# P(older_girl): 48.85
# P(both | older): 0.5008186655751126
# P(both | either): 0.33112313937753723
# P(either_girls): 73.9
# P(both_girls): 24.47
# P(older_girl): 48.86
# P(both | older): 0.5008186655751126
# P(both | either): 0.33112313937753723
# P(either_girls): 73.9
# P(both_girls): 24.47
# P(older_girl): 48.86
# P(both | older): 0.5009208103130756
# P(both | either): 0.33121363820863214
# P(either_girls): 73.91
# P(both_girls): 24.48
# P(older_girl): 48.870000000000005
# P(both | older): 0.5010229132569558
# P(both | either): 0.3313041125541126
# P(either_girls): 73.92
# P(both_girls): 24.490000000000002
# P(older_girl): 48.88
# P(both | older): 0.5009204336265085
# P(both | either): 0.3312592993372109
# P(either_girls): 73.92999999999999
# P(both_girls): 24.490000000000002
# P(older_girl): 48.89
# P(both | older): 0.5009204336265085
# P(both | either): 0.3312144982418177
# P(either_girls): 73.94
# P(both_girls): 24.490000000000002
# P(older_girl): 48.89
# P(both | older): 0.5010224948875256
# P(both | either): 0.33130493576741044
# P(either_girls): 73.95
# P(both_girls): 24.5
# P(older_girl): 48.9
# P(both | older): 0.5010224948875256
# P(both | either): 0.33126014061654946
# P(either_girls): 73.96000000000001
# P(both_girls): 24.5
# P(older_girl): 48.9
# P(both | older): 0.5009200572480066
# P(both | either): 0.33121535757739623
# P(either_girls): 73.97
# P(both_girls): 24.5
# P(older_girl): 48.91
# P(both | older): 0.5010220768601799
# P(both | either): 0.3313057583130576
# P(either_girls): 73.98
# P(both_girls): 24.51
# P(older_girl): 48.92
# P(both | older): 0.5010220768601799
# P(both | either): 0.3313057583130576
# P(either_girls): 73.98
# P(both_girls): 24.51
# P(older_girl): 48.92
# P(both | older): 0.5010220768601799
# P(both | either): 0.3313057583130576
# P(either_girls): 73.98
# P(both_girls): 24.51
# P(older_girl): 48.92
# P(both | older): 0.5009196811771919
# P(both | either): 0.33126098121367753
# P(either_girls): 73.99
# P(both_girls): 24.51
# P(older_girl): 48.93
# P(both | older): 0.5009196811771919
# P(both | either): 0.3312162162162162
# P(either_girls): 74.0
# P(both_girls): 24.51
# P(older_girl): 48.93
# P(both | older): 0.5009196811771919
# P(both | either): 0.33117146331576813
# P(either_girls): 74.00999999999999
# P(both_girls): 24.51
# P(older_girl): 48.93
# P(both | older): 0.5009196811771919
# P(both | either): 0.3311267225074304
# P(either_girls): 74.02
# P(both_girls): 24.51
# P(older_girl): 48.93
# P(both | older): 0.5010216591744994
# P(both | either): 0.33121707415912466
# P(either_girls): 74.03
# P(both_girls): 24.52
# P(older_girl): 48.94
# P(both | older): 0.5009193054136875
# P(both | either): 0.331172339276067
# P(either_girls): 74.03999999999999
# P(both_girls): 24.52
# P(older_girl): 48.949999999999996
# P(both | older): 0.5010212418300654
# P(both | either): 0.3312626603646185
# P(either_girls): 74.05000000000001
# P(both_girls): 24.529999999999998
# P(older_girl): 48.96
# P(both | older): 0.5010212418300654
# P(both | either): 0.3312179314069673
# P(either_girls): 74.06
# P(both_girls): 24.529999999999998
# P(older_girl): 48.96
# P(both | older): 0.5010212418300654
# P(both | either): 0.3312179314069673
# P(either_girls): 74.06
# P(both_girls): 24.529999999999998
# P(older_girl): 48.96
# P(both | older): 0.5011231366142537
# P(both | either): 0.3313082219522074
# P(either_girls): 74.07000000000001
# P(both_girls): 24.54
# P(older_girl): 48.97
# P(both | older): 0.5011231366142537
# P(both | either): 0.3313082219522074
# P(either_girls): 74.07000000000001
# P(both_girls): 24.54
# P(older_girl): 48.97
# P(both | older): 0.5011231366142537
# P(both | either): 0.3313082219522074
# P(either_girls): 74.07000000000001
# P(both_girls): 24.54
# P(older_girl): 48.97
# P(both | older): 0.5010208248264598
# P(both | either): 0.3312634989200864
# P(either_girls): 74.08
# P(both_girls): 24.54
# P(older_girl): 48.980000000000004
# P(both | older): 0.5009185548071035
# P(both | either): 0.33121878796058846
# P(either_girls): 74.09
# P(both_girls): 24.54
# P(older_girl): 48.99
# P(both | older): 0.5009185548071035
# P(both | either): 0.33121878796058846
# P(either_girls): 74.09
# P(both_girls): 24.54
# P(older_girl): 48.99
# P(both | older): 0.5009185548071035
# P(both | either): 0.3311740890688259
# P(either_girls): 74.1
# P(both_girls): 24.54
# P(older_girl): 48.99
# P(both | older): 0.5008163265306123
# P(both | either): 0.33112940223991366
# P(either_girls): 74.11
# P(both_girls): 24.54
# P(older_girl): 49.0
# P(both | older): 0.5008163265306123
# P(both | either): 0.3310847274689692
# P(either_girls): 74.11999999999999
# P(both_girls): 24.54
# P(older_girl): 49.0
# P(both | older): 0.5008163265306123
# P(both | either): 0.3310400647511129
# P(either_girls): 74.13
# P(both_girls): 24.54
# P(older_girl): 49.0
# P(both | older): 0.5007141399714344
# P(both | either): 0.3309954140814675
# P(either_girls): 74.14
# P(both_girls): 24.54
# P(older_girl): 49.01
# P(both | older): 0.5006119951040392
# P(both | either): 0.33095077545515844
# P(either_girls): 74.15
# P(both_girls): 24.54
# P(older_girl): 49.02
# P(both | older): 0.5006119951040392
# P(both | either): 0.3309061488673139
# P(either_girls): 74.16
# P(both_girls): 24.54
# P(older_girl): 49.02
# P(both | older): 0.5006119951040392
# P(both | either): 0.3308615343130646
# P(either_girls): 74.17
# P(both_girls): 24.54
# P(older_girl): 49.02
# P(both | older): 0.5005098919029166
# P(both | either): 0.3308169317875438
# P(either_girls): 74.18
# P(both_girls): 24.54
# P(older_girl): 49.03
# P(both | older): 0.5006117455138662
# P(both | either): 0.3309071303410163
# P(either_girls): 74.19
# P(both_girls): 24.55
# P(older_girl): 49.04
# P(both | older): 0.5005096839959225
# P(both | either): 0.3308625336927224
# P(either_girls): 74.2
# P(both_girls): 24.55
# P(older_girl): 49.05
# P(both | older): 0.5004076640847941
# P(both | either): 0.3308179490634685
# P(either_girls): 74.21
# P(both_girls): 24.55
# P(older_girl): 49.059999999999995
# P(both | older): 0.5003056857550439
# P(both | either): 0.33077337644839666
# P(either_girls): 74.22
# P(both_girls): 24.55
# P(older_girl): 49.07
# P(both | older): 0.5003056857550439
# P(both | either): 0.33072881584265124
# P(either_girls): 74.22999999999999
# P(both_girls): 24.55
# P(older_girl): 49.07
# P(both | older): 0.5004074979625102
# P(both | either): 0.3308189655172414
# P(either_girls): 74.24
# P(both_girls): 24.560000000000002
# P(older_girl): 49.08
# P(both | older): 0.5004074979625102
# P(both | either): 0.3308189655172414
# P(either_girls): 74.24
# P(both_girls): 24.560000000000002
# P(older_girl): 49.08
# P(both | older): 0.5005092686901609
# P(both | either): 0.33090909090909093
# P(either_girls): 74.25
# P(both_girls): 24.57
# P(older_girl): 49.09
# P(both | older): 0.5004073319755601
# P(both | either): 0.3308645300296256
# P(either_girls): 74.26
# P(both_girls): 24.57
# P(older_girl): 49.1
# P(both | older): 0.5005090612909794
# P(both | either): 0.3309546250168305
# P(either_girls): 74.27
# P(both_girls): 24.58
# P(older_girl): 49.11
# P(both | older): 0.5006107491856677
# P(both | either): 0.3310446957458266
# P(either_girls): 74.28
# P(both_girls): 24.59
# P(older_girl): 49.120000000000005
# P(both | older): 0.5007123956849175
# P(both | either): 0.33113474222641004
# P(either_girls): 74.29
# P(both_girls): 24.6
# P(older_girl): 49.13
# P(both | older): 0.5006105006105006
# P(both | either): 0.3310901749663526
# P(either_girls): 74.3
# P(both_girls): 24.6
# P(older_girl): 49.14
# P(both | older): 0.5005086469989827
# P(both | either): 0.3310456197012515
# P(either_girls): 74.31
# P(both_girls): 24.6
# P(older_girl): 49.15
# P(both | older): 0.5005086469989827
# P(both | either): 0.3310456197012515
# P(either_girls): 74.31
# P(both_girls): 24.6
# P(older_girl): 49.15
# P(both | older): 0.5005086469989827
# P(both | either): 0.3310010764262648
# P(either_girls): 74.32
# P(both_girls): 24.6
# P(older_girl): 49.15
# P(both | older): 0.500406834825061
# P(both | either): 0.3309565451365532
# P(either_girls): 74.33
# P(both_girls): 24.6
# P(older_girl): 49.16
# P(both | older): 0.5003050640634533
# P(both | either): 0.3309120258272801
# P(either_girls): 74.33999999999999
# P(both_girls): 24.6
# P(older_girl): 49.17
# P(both | older): 0.5003050640634533
# P(both | either): 0.3309120258272801
# P(either_girls): 74.33999999999999
# P(both_girls): 24.6
# P(older_girl): 49.17
# P(both | older): 0.5004066693777959
# P(both | either): 0.33100201748486885
# P(either_girls): 74.35000000000001
# P(both_girls): 24.610000000000003
# P(older_girl): 49.18
# P(both | older): 0.5004066693777959
# P(both | either): 0.33100201748486885
# P(either_girls): 74.35000000000001
# P(both_girls): 24.610000000000003
# P(older_girl): 49.18
# P(both | older): 0.5004066693777959
# P(both | either): 0.3309575040344271
# P(either_girls): 74.36
# P(both_girls): 24.610000000000003
# P(older_girl): 49.18
# P(both | older): 0.5004066693777959
# P(both | either): 0.3309130025547936
# P(either_girls): 74.37
# P(both_girls): 24.610000000000003
# P(older_girl): 49.18
# P(both | older): 0.5004066693777959
# P(both | either): 0.3309130025547936
# P(either_girls): 74.37
# P(both_girls): 24.610000000000003
# P(older_girl): 49.18
# P(both | older): 0.5004066693777959
# P(both | either): 0.3309130025547936
# P(either_girls): 74.37
# P(both_girls): 24.610000000000003
# P(older_girl): 49.18
# P(both | older): 0.5005082333807684
# P(both | either): 0.3310029577843506
# P(either_girls): 74.38
# P(both_girls): 24.62
# P(older_girl): 49.19
# P(both | older): 0.5004065040650406
# P(both | either): 0.3309584621588923
# P(either_girls): 74.39
# P(both_girls): 24.62
# P(older_girl): 49.2
# P(both | older): 0.5003048160942898
# P(both | either): 0.3309139784946237
# P(either_girls): 74.4
# P(both_girls): 24.62
# P(older_girl): 49.21
# P(both | older): 0.5003048160942898
# P(both | either): 0.3308695067867222
# P(either_girls): 74.41
# P(both_girls): 24.62
# P(older_girl): 49.21
# P(both | older): 0.5004063388866314
# P(both | either): 0.33095941951088415
# P(either_girls): 74.42
# P(both_girls): 24.63
# P(older_girl): 49.220000000000006
# P(both | older): 0.5005078204346943
# P(both | either): 0.33104930807470107
# P(either_girls): 74.42999999999999
# P(both_girls): 24.64
# P(older_girl): 49.230000000000004
# P(both | older): 0.5005078204346943
# P(both | either): 0.3310048361096185
# P(either_girls): 74.44
# P(both_girls): 24.64
# P(older_girl): 49.230000000000004
# P(both | older): 0.5005078204346943
# P(both | either): 0.3309603760913365
# P(either_girls): 74.45
# P(both_girls): 24.64
# P(older_girl): 49.230000000000004
# P(both | older): 0.5004061738424046
# P(both | either): 0.33091592801504166
# P(either_girls): 74.46000000000001
# P(both_girls): 24.64
# P(older_girl): 49.24
# P(both | older): 0.5004061738424046
# P(both | either): 0.3308714918759232
# P(either_girls): 74.47
# P(both_girls): 24.64
# P(older_girl): 49.24
# P(both | older): 0.5004061738424046
# P(both | either): 0.3308270676691729
# P(either_girls): 74.48
# P(both_girls): 24.64
# P(older_girl): 49.24
# P(both | older): 0.5004061738424046
# P(both | either): 0.33078265538998525
# P(either_girls): 74.49
# P(both_girls): 24.64
# P(older_girl): 49.24
# P(both | older): 0.500507614213198
# P(both | either): 0.3308724832214765
# P(either_girls): 74.5
# P(both_girls): 24.65
# P(older_girl): 49.25
# P(both | older): 0.5006090133982948
# P(both | either): 0.33096228694135016
# P(either_girls): 74.51
# P(both_girls): 24.66
# P(older_girl): 49.26
# P(both | older): 0.5005074081591232
# P(both | either): 0.3309178743961353
# P(either_girls): 74.52
# P(both_girls): 24.66
# P(older_girl): 49.27
# P(both | older): 0.5006087662337663
# P(both | either): 0.33100764792700926
# P(either_girls): 74.53
# P(both_girls): 24.67
# P(older_girl): 49.28
# P(both | older): 0.5005072022722662
# P(both | either): 0.33096324121277165
# P(either_girls): 74.53999999999999
# P(both_girls): 24.67
# P(older_girl): 49.29
# P(both | older): 0.5006085192697769
# P(both | either): 0.3310529845741113
# P(either_girls): 74.55000000000001
# P(both_girls): 24.68
# P(older_girl): 49.3
# P(both | older): 0.5007097951733929
# P(both | either): 0.3311427038626609
# P(either_girls): 74.56
# P(both_girls): 24.69
# P(older_girl): 49.309999999999995
# P(both | older): 0.5006082725060828
# P(both | either): 0.3310982969022395
# P(either_girls): 74.57000000000001
# P(both_girls): 24.69
# P(older_girl): 49.32
# P(both | older): 0.5006082725060828
# P(both | either): 0.33105390185036204
# P(either_girls): 74.58
# P(both_girls): 24.69
# P(older_girl): 49.32
# P(both | older): 0.5005067909993919
# P(both | either): 0.3310095187022389
# P(either_girls): 74.59
# P(both_girls): 24.69
# P(older_girl): 49.33
# P(both | older): 0.5006080259424402
# P(both | either): 0.33109919571045576
# P(either_girls): 74.6
# P(both_girls): 24.7
# P(older_girl): 49.34
# P(both | older): 0.5005065856129686
# P(both | either): 0.3310548183889559
# P(either_girls): 74.61
# P(both_girls): 24.7
# P(older_girl): 49.35
# P(both | older): 0.5005065856129686
# P(both | either): 0.3310548183889559
# P(either_girls): 74.61
# P(both_girls): 24.7
# P(older_girl): 49.35
# P(both | older): 0.5006077795786061
# P(both | either): 0.33114446529080677
# P(either_girls): 74.62
# P(both_girls): 24.709999999999997
# P(older_girl): 49.36
# P(both | older): 0.5007089325501317
# P(both | either): 0.3312340881682969
# P(either_girls): 74.63
# P(both_girls): 24.72
# P(older_girl): 49.370000000000005
# P(both | older): 0.5007089325501317
# P(both | either): 0.3312340881682969
# P(either_girls): 74.63
# P(both_girls): 24.72
# P(older_girl): 49.370000000000005
# P(both | older): 0.5007089325501317
# P(both | either): 0.3311897106109325
# P(either_girls): 74.64
# P(both_girls): 24.72
# P(older_girl): 49.370000000000005
